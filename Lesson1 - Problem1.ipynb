# %%
ice_cream_rating = 4
sleeping_rating = 7

# %%
first_name = input("what is your first name")
# Out:
# what is your first name alex

# %%
last_name = input("what is your last name")
# Out:
# what is your last name olsen

# %%
my_name = first_name +" " + last_name
print(my_name)
# Out:
# alex olsen

# %%
happiness_rating = (ice_cream_rating+sleeping_rating)/2

# %%
type(first_name)
# Out:
# str

# %%
type(ice_cream_rating)
# Out:
# int

# %%
type(sleeping_rating)
# Out:
# int

# %% [markdown]
# The data types make sense because I have a very basic understanding of computer science

# %%
print("My name is " + (first_name) + " and I give eating ice cream a score of " + str(ice_cream_rating) + " out of 10!")
# Out:
# My name is alex and I give eating ice cream a score of 4 out of 10!

# %%
print("I am " + (my_name) + " and my sleeping enjoyment rating is " + str(sleeping_rating) +"/10")
# Out:
# I am alex olsen and my sleeping enjoyment rating is 7/10

# %%
# %precision %.2f
# Out:
# '%.2f'

# %%
print("Based on the factors above, my happiness rating is " + str(happiness_rating) + " out of 10, or " + str((happiness_rating/10)*100) + "%!")
# Out:
# Based on the factors above, my happiness rating is 5.5 out of 10, or 55.00000000000001%!
